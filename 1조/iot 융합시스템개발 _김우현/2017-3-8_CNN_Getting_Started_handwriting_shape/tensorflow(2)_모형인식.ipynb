# %%
# #colab 데이터 업로드
# # 구글드라이브에 폴더를 업로드하고 마운트
# from google.colab import drive
# drive.mount('/gdrive')
# #확인코드
# !ls /gdrive/My\ Drive/handwriting_shape/

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# 1.데이터 생성하기
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'handwriting_shape/train',
    target_size=(24, 24),
    batch_size=3,
    class_mode='categorical')

train_datagen = ImageDataGenerator(rescale = 1./255,
                                  rotation_range = 10,
                                  width_shift_range = 0.2,
                                  height_shift_range = 0.2,
                                  shear_range = 0.7,
                                  zoom_range = [0.9, 2.2],
                                  horizontal_flip = True,
                                  vertical_flip = True,
                                  fill_mode = 'nearest')

test_generator = test_datagen.flow_from_directory(
    'handwriting_shape/test',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical')

# 2.모델 구성하기

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
         activation='relu',
         input_shape=(24,24,3)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3.모델 학습과정 설정하기
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=15*100,
    epochs=200,
    validation_data=test_generator,
    validation_steps=5)

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Found 45 images belonging to 3 classes.
# Found 241 images belonging to 3 classes.
# Epoch 1/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 3.8810 - val_accuracy: 0.6667
# Epoch 2/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 5.5994e-07 - accuracy: 1.0000 - val_loss: 4.1255 - val_accuracy: 0.6667
# Epoch 3/200
# 1500/1500 [==============================] - 26s 18ms/step - loss: 1.2588e-07 - accuracy: 1.0000 - val_loss: 4.2449 - val_accuracy: 0.6667
# Epoch 4/200
# 1500/1500 [==============================] - 25s 17ms/step - loss: 3.9313e-08 - accuracy: 1.0000 - val_loss: 4.4064 - val_accuracy: 0.6000
# Epoch 5/200
# 1500/1500 [==============================] - 23s 15ms/step - loss: 1.3245e-08 - accuracy: 1.0000 - val_loss: 4.6342 - val_accuracy: 0.6000
# Epoch 6/200
# 1500/1500 [==============================] - 25s 17ms/step - loss: 1.7219e-09 - accuracy: 1.0000 - val_loss: 4.7859 - val_accuracy: 0.6000
# Epoch 7/200
# 1500/1500 [==============================] - 23s 15ms/step - loss: 1.3245e-10 - accuracy: 1.0000 - val_loss: 4.7933 - val_accuracy: 0.6000
# Epoch 8/200
# 1500/1500 [==============================] - 25s 17ms/step - loss: 4.9008e-09 - accuracy: 1.0000 - val_loss: 4.3342 - val_accuracy: 0.6000
# Epoch 9/200
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0331 - accuracy: 0.9971 - val_loss: 6.3230 - val_accuracy: 0.6000
# Epoch 10/200
# 1500/1500 [==============================] - 25s 16ms/step - loss: 5.2171e-07 - accuracy: 1.0000 - val_loss: 6.3853 - val_accuracy: 0.6000
# Epoch 11/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 2.7037e-07 - accuracy: 1.0000 - val_loss: 6.4480 - val_accuracy: 0.6000
# Epoch 12/200
# 1500/1500 [==============================] - 25s 16ms/step - loss: 1.3230e-07 - accuracy: 1.0000 - val_loss: 6.4900 - val_accuracy: 0.6000
# Epoch 13/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 6.5353e-08 - accuracy: 1.0000 - val_loss: 6.5692 - val_accuracy: 0.6000
# Epoch 14/200
# 1500/1500 [==============================] - 23s 15ms/step - loss: 2.7842e-08 - accuracy: 1.0000 - val_loss: 6.6179 - val_accuracy: 0.6000
# Epoch 15/200
# 1500/1500 [==============================] - 24s 16ms/step - loss: 1.1868e-08 - accuracy: 1.0000 - val_loss: 6.6537 - val_accuracy: 0.6000
# Epoch 16/200
# 1500/1500 [==============================] - 25s 17ms/step - loss: 5.8015e-09 - accuracy: 1.0000 - val_loss: 6.7025 - val_accuracy: 0.6000
# Epoch 17/200
# 1500/1500 [==============================] - 23s 15ms/step - loss: 1.5895e-10 - accuracy: 1.0000 - val_loss: 6.7269 - val_accuracy: 0.6000
# Epoch 18/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.7441 - val_accuracy: 0.6000
# Epoch 19/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.7673 - val_accuracy: 0.6000
# Epoch 20/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8013 - val_accuracy: 0.6000
# Epoch 21/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8515 - val_accuracy: 0.6000
# Epoch 22/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.9231 - val_accuracy: 0.6000
# Epoch 23/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.0214 - val_accuracy: 0.6000
# Epoch 24/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.1435 - val_accuracy: 0.6000
# Epoch 25/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.2862 - val_accuracy: 0.6000
# Epoch 26/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4359 - val_accuracy: 0.5333
# Epoch 27/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.5822 - val_accuracy: 0.5333
# Epoch 28/200
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.7218 - val_accuracy: 0.5333
# Epoch 29/200
#  690/1500 [============>.................] - ETA: 13s - loss: 0.0000e+00 - accuracy: 1.0000
