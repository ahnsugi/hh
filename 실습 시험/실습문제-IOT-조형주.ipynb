# %% [markdown]
# ## 1. random 함수를 활용하여 로또 추첨기 만들기

# %%
import random
k = 0
max = 0
lmax=[]
second = []
second_cnt=0
bonus = 25
lotto = [12,17,28,41,43,44]
while True:
    count = 0
    l = random.sample(range(1,45),6)
    for i in l:
        for j in lotto:
            if(i==j):
                count+=1
        #print("{}   {}개 적중!".format(l, count))
    if(k%10000==0):
        print(k, "번째 휴지조각 구매중")
    if(max < count):
        max = count
        lmax = l
    
    if(max == 6):
        print(k, "번째 1등 당첨!", l)
        break
    if(count==5):
        if(bonus in l):
            print(k, "번째 2등 당첨!", l)
            second.append(l)
            second_cnt+=1            
    k+=1
    
print("2등의 숫자",second_cnt)
for y in second:
    print(y)
# Out:
# 0 번째 휴지조각 구매중
# 10000 번째 휴지조각 구매중
# 20000 번째 휴지조각 구매중
# 30000 번째 휴지조각 구매중
# 40000 번째 휴지조각 구매중
# 50000 번째 휴지조각 구매중
# 60000 번째 휴지조각 구매중
# 70000 번째 휴지조각 구매중
# 80000 번째 휴지조각 구매중
# 90000 번째 휴지조각 구매중
# 100000 번째 휴지조각 구매중
# 110000 번째 휴지조각 구매중
# 116728 번째 2등 당첨! [25, 41, 44, 28, 17, 43]
# 120000 번째 휴지조각 구매중
# 130000 번째 휴지조각 구매중
# 140000 번째 휴지조각 구매중
# 150000 번째 휴지조각 구매중
# 160000 번째 휴지조각 구매중
# 170000 번째 휴지조각 구매중
# 180000 번째 휴지조각 구매중
# 190000 번째 휴지조각 구매중
# 200000 번째 휴지조각 구매중
# 210000 번째 휴지조각 구매중
# 220000 번째 휴지조각 구매중
# 230000 번째 휴지조각 구매중
# 240000 번째 휴지조각 구매중
# 250000 번째 휴지조각 구매중
# 260000 번째 휴지조각 구매중
# 270000 번째 휴지조각 구매중
# 280000 번째 휴지조각 구매중
# 290000 번째 휴지조각 구매중
# 300000 번째 휴지조각 구매중
# 310000 번째 휴지조각 구매중
# 320000 번째 휴지조각 구매중
# 330000 번째 휴지조각 구매중
# 340000 번째 휴지조각 구매중
# 350000 번째 휴지조각 구매중
# 360000 번째 휴지조각 구매중
# 370000 번째 휴지조각 구매중
# 380000 번째 휴지조각 구매중
# 390000 번째 휴지조각 구매중
# 400000 번째 휴지조각 구매중
# 410000 번째 휴지조각 구매중
# 420000 번째 휴지조각 구매중
# 430000 번째 휴지조각 구매중
# 440000 번째 휴지조각 구매중
# 450000 번째 휴지조각 구매중
# 460000 번째 휴지조각 구매중
# 470000 번째 휴지조각 구매중
# 480000 번째 휴지조각 구매중
# 490000 번째 휴지조각 구매중
# 500000 번째 휴지조각 구매중
# 510000 번째 휴지조각 구매중
# 520000 번째 휴지조각 구매중
# 530000 번째 휴지조각 구매중
# 540000 번째 휴지조각 구매중
# 550000 번째 휴지조각 구매중
# 560000 번째 휴지조각 구매중
# 570000 번째 휴지조각 구매중
# 580000 번째 휴지조각 구매중
# 590000 번째 휴지조각 구매중
# 600000 번째 휴지조각 구매중
# 2960000 번째 휴지조각 구매중
# 2970000 번째 휴지조각 구매중
# 2980000 번째 휴지조각 구매중
# 2990000 번째 휴지조각 구매중
# 3000000 번째 휴지조각 구매중
# 3010000 번째 휴지조각 구매중
# 3020000 번째 휴지조각 구매중
# 3030000 번째 휴지조각 구매중
# 3040000 번째 휴지조각 구매중
# 3050000 번째 휴지조각 구매중
# 3060000 번째 휴지조각 구매중
# 3070000 번째 휴지조각 구매중
# 3080000 번째 휴지조각 구매중
# 3088836 번째 1등 당첨! [17, 44, 12, 28, 41, 43]
# 2등의 숫자 2
# [25, 41, 44, 28, 17, 43]
# [25, 41, 44, 43, 12, 17]

# %% [markdown]
# ## 2. 3단, 6단을 제외한 구구단 만들기(반복문사용)

# %%
for j in range(2,10):
    if (j == 3) or (j==6):
        continue
    print(j, "단")
    for i in range(1,10):
        print("{} X {} = {}".format(j,i,j*i))
    print()
# Out:
# 2 단
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
#
# 4 단
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
#
# 5 단
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# 7 단
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
#
# 8 단
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
#
# 9 단
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# ## 3. 리스트 중복을 제거하고 역순으로 정렬하기

# %%
a = [1,1,1,4,2,5,6,7,3,5,6,7,6,7,8,4,3,5,6,7,2,6,2,4,2,9,8,6,7,4,5,3,2]
b = set(a)
c = sorted(list(b), reverse = True)
print(c)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ## 4. 5개 이상의 특징을 가진 동물분류기(미완성)

# %%
import random
import numpy as np

data = []
#개, 돼지, 호랑이, 얼룩말, 치타
#(높이, 길이, 무게, 먹는 양, 달리기속도)
for i in range(50):
    #data.append(      키높이            머리에서 꼬리까지 길이      몸무게                 샤료먹는 양             달리기 속도)
    data.append([random.randint(20, 40),random.randint(30, 80), random.randint(20, 50), random.randint(1, 20), random.randint(10, 40)]) #개
    data.append([random.randint(40, 60),random.randint(60, 150), random.randint(100, 150), random.randint(20, 30), random.randint(5, 10)]) #돼지
    data.append([random.randint(50, 100),random.randint(130, 200), random.randint(200, 250), random.randint(10, 25), random.randint(50, 80)]) #호랑이
    data.append([random.randint(80, 120),random.randint(100, 150), random.randint(90, 120), random.randint(10, 15), random.randint(30, 90)]) #얼룩말
    data.append([random.randint(50, 80),random.randint(80, 130), random.randint(80, 100), random.randint(5, 15), random.randint(80, 110)]) #치타

points = [[random.randint(20, 120),random.randint(60, 200),random.randint(20, 250),random.randint(1, 30),random.randint(5, 110)],
                 [random.randint(20, 120),random.randint(60, 200),random.randint(20, 250),random.randint(1, 30),random.randint(5, 110)],
                 [random.randint(20, 120),random.randint(60, 200),random.randint(20, 250),random.randint(1, 30),random.randint(5, 110)],
                 [random.randint(20, 120),random.randint(60, 200),random.randint(20, 250),random.randint(1, 30),random.randint(5, 110)],
                 [random.randint(20, 120),random.randint(60, 200),random.randint(20, 250),random.randint(1, 30),random.randint(5, 110)]]


def dist(x,y):
    return np.sqrt((x[0]-y[0])**2 +(x[1]-y[1])**2+(x[2]-y[2])**2+(x[3]-y[3])**2+(x[4]-y[4])**2)

#각 데이터를 기준으로 가장 가까운 점을 찾는다
temp = [[],[],[],[],[]]
for i in data:
    distance = []
    for k in range(0,5):
        distance.append(dist(points[k], i))
    temp[ distance.index( min(distance) ) ].append(i)
# Out:
#   File "<ipython-input-24-50b284e410d6>", line 35
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
len(points)
# Out:
# 5

# %% [markdown]
# ## 5. 피보나치 수열 출력 프로그램

# %%
n = [0, 1, 1]

for i in range(2, 101):
    print("{:3d} 번째 피보나치 수: {}".format(i,n[2]))
    #print(i, "번째 피보나치 수 : ", n[2])
    n[0] = n[1]
    n[1] = n[2]
    n[2] = n[0]+n[1]
# Out:
#   2 번째 피보나치 수: 1
#   3 번째 피보나치 수: 2
#   4 번째 피보나치 수: 3
#   5 번째 피보나치 수: 5
#   6 번째 피보나치 수: 8
#   7 번째 피보나치 수: 13
#   8 번째 피보나치 수: 21
#   9 번째 피보나치 수: 34
#  10 번째 피보나치 수: 55
#  11 번째 피보나치 수: 89
#  12 번째 피보나치 수: 144
#  13 번째 피보나치 수: 233
#  14 번째 피보나치 수: 377
#  15 번째 피보나치 수: 610
#  16 번째 피보나치 수: 987
#  17 번째 피보나치 수: 1597
#  18 번째 피보나치 수: 2584
#  19 번째 피보나치 수: 4181
#  20 번째 피보나치 수: 6765
#  21 번째 피보나치 수: 10946
#  22 번째 피보나치 수: 17711
#  23 번째 피보나치 수: 28657
#  24 번째 피보나치 수: 46368
#  25 번째 피보나치 수: 75025
#  26 번째 피보나치 수: 121393
#  27 번째 피보나치 수: 196418
#  28 번째 피보나치 수: 317811
#  29 번째 피보나치 수: 514229
