# %% [markdown]
# ## 1. random 함수를 활용하여 로또 추첨기

# %%
import random

Lotto = sorted(random.sample(range(1,46),6))

# %%
print(Lotto)

# %% [markdown]
# ## 2. 구구단 3단, 6단 제외

# %%
for i in range(2,10):
    if ( i == 3 or i == 6):
        continue
    for j in range(2,10):
        print(i,'X',j,'=',i*j)

# %% [markdown]
# ## 3. 리스트 중복을 제거하고 역순으로 정렬

# %%
a = [1,1,1,4,2,5,6,7,3,5,6,7,6,7,8,4,3,5,6,7,2,6,2,4,2,9,8,6,7,4,5,3,2]

# %%
a = list(set(a))

# %%
a.sort(reverse =True)

# %%
print(a)

# %% [markdown]
# ## 4. 특징이 5개 이상인 동물 분류 (아직)

# %%
import random
import numpy as np
 # 당도 0~5 , 크기 , 색깔 , 단단 구분
animal = []
tiger = [] # 호랑이 0 
eagle = [] # 독수리 1
owl = [] # 부엉이 2
cow = [] # 소 3
for i in range(50):
    tiger.append([random.randint(0, 5), random.randint(0, 5), random.randint(0, 5), random.randint(0, 5),0])
    eagle.append([random.randint(0, 5), random.randint(0, 5), random.randint(0, 5), random.randint(0, 5),1])
    owl.append([random.randint(0, 5), random.randint(0, 5), random.randint(0, 5), random.randint(0, 5),2])
    cow.append([random.randint(0, 5), random.randint(0, 5), random.randint(0, 5), random.randint(0, 5),3])

# %%
def distance(x,y):
    #두 점 사이의 거리를 구하는 함수
    return np.sqrt(pow((x[0]-y[0]),2)+pow((x[1]-y[1]),2)+pow((x[2]-y[2]),2)+pow((x[3]-y[3]),2))

def knn(x,y,k):
    result=[]
    animal_0, animal_1, animal_2, animal_3, animal_4 = 0
    
    for i in range(len(y)):
        result.append([distance(x,y[i]),y[i][2]])
    result.sort()
    for i in range(k):
        if (result[i][1]==1):
            cnt +=1
    if (animal[i][i][1] == 0):
        print ("호랑이입니다.")
    elif(animal[i][i][1] == 1):
        print("독수리입니다.")
    elif(animal[i][i][1] == 2):
        print("부엉이입니다.")
    else:
        print("소입니다.")

# %% [markdown]
# ## 5. 1~100 피보나치 수열

# %%
i = 0
j = 1
tmp = 0

# %%
for a in range(1,101):
    tmp = i + j
    print("i =",i,"j =",j,"i+j =",tmp)
    i = j
    j = tmp
# Out:
# i = 0 j = 1 i+j = 1
# i = 1 j = 1 i+j = 2
# i = 1 j = 2 i+j = 3
# i = 2 j = 3 i+j = 5
# i = 3 j = 5 i+j = 8
# i = 5 j = 8 i+j = 13
# i = 8 j = 13 i+j = 21
# i = 13 j = 21 i+j = 34
# i = 21 j = 34 i+j = 55
# i = 34 j = 55 i+j = 89
# i = 55 j = 89 i+j = 144
# i = 89 j = 144 i+j = 233
# i = 144 j = 233 i+j = 377
# i = 233 j = 377 i+j = 610
# i = 377 j = 610 i+j = 987
# i = 610 j = 987 i+j = 1597
# i = 987 j = 1597 i+j = 2584
# i = 1597 j = 2584 i+j = 4181
# i = 2584 j = 4181 i+j = 6765
# i = 4181 j = 6765 i+j = 10946
# i = 6765 j = 10946 i+j = 17711
# i = 10946 j = 17711 i+j = 28657
# i = 17711 j = 28657 i+j = 46368
# i = 28657 j = 46368 i+j = 75025
# i = 46368 j = 75025 i+j = 121393
# i = 75025 j = 121393 i+j = 196418
# i = 121393 j = 196418 i+j = 317811
# i = 196418 j = 317811 i+j = 514229
# i = 317811 j = 514229 i+j = 832040
# i = 514229 j = 832040 i+j = 1346269
# i = 832040 j = 1346269 i+j = 2178309
# i = 1346269 j = 2178309 i+j = 3524578
# i = 2178309 j = 3524578 i+j = 5702887
# i = 3524578 j = 5702887 i+j = 9227465
# i = 5702887 j = 9227465 i+j = 14930352
# i = 9227465 j = 14930352 i+j = 24157817
# i = 14930352 j = 24157817 i+j = 39088169
# i = 24157817 j = 39088169 i+j = 63245986
