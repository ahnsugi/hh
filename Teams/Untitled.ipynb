# %%
import tensorflow as tf

# %%
import  matplotlib.pyplot as plt

# %%
plt.plot(1,2,marker='o', linestyle='',color='red')
plt.plot(2,2,marker='o', linestyle='',color='red')
plt.plot(3,2,marker='o', linestyle='',color='blue')

# %%
import numpy as np
import random

# %%
r = []
b = []

for i in range(100):
    r.append([random.randint(40,80),random.randint(130,180),1])
    b.append([random.randint(60,100),random.randint(150,200),0])

# %%
for i in range(0,100):
    plt.plot(r[i][0],r[i][1],marker='o', linestyle='',color='red')
    plt.plot(b[i][0],b[i][1],marker='o', linestyle='',color='blue')
k = [70,165,2]
plt.plot(k[0],k[1],marker='*', linestyle='',color='black')

# %%
def distance(x,y):
    return (np.sqrt(pow((x[0]-y[0]),2)+pow((x[1]-y[1]),2)))

# %%
new = [62,172]

# %%
distance(new,r[0])
# Out:
# 36.49657518178932

# %%
d1 = []
for i in range (0,100):
    d1.append([distance(new,r[i]),r[i][2]])
    d1.append([distance(new,b[i]),b[i][2]])

# %%
d1.sort()

# %%
print(d1)
# Out:
# [[1.0, 0], [2.23606797749979, 0], [2.23606797749979, 1], [2.8284271247461903, 0], [3.0, 1], [3.1622776601683795, 1], [3.605551275463989, 0], [3.605551275463989, 0], [5.656854249492381, 0], [5.830951894845301, 0], [6.4031242374328485, 1], [7.615773105863909, 0], [7.615773105863909, 1], [7.810249675906654, 0], [7.810249675906654, 0], [8.06225774829855, 1], [8.06225774829855, 1], [8.246211251235321, 1], [8.246211251235321, 1], [8.54400374531753, 1], [8.94427190999916, 1], [9.055385138137417, 0], [9.433981132056603, 0], [9.486832980505138, 1], [9.848857801796104, 1], [10.04987562112089, 1], [10.44030650891055, 1], [10.770329614269007, 0], [10.770329614269007, 1], [10.816653826391969, 0], [11.180339887498949, 1], [11.313708498984761, 1], [11.40175425099138, 0], [11.40175425099138, 1], [11.661903789690601, 1], [11.704699910719626, 0], [12.0, 0], [12.083045973594572, 1], [12.206555615733702, 1], [12.36931687685298, 0], [12.529964086141668, 0], [13.0, 0], [13.038404810405298, 0], [13.3416640
# ...

# %%
woman = 0
man = 0
for i in range(0,100):
    if (d1[i][0] <= 7):
        if (d1[i][1] == 1):
            man += 1
        elif(d1[i][1] == 0):
            woman += 1

if(woman > man):
    print('여자입니다.')
elif(woman < man):
    print('남자입니다.')
else:
    print('잘못된값입니다.')
# Out:
# 여자입니다.

# %%
import  matplotlib.pyplot as plt
import numpy as np
import random
r = []
b = []
d1 = []
print(z)
woman = 0
man = 0

new = [52,168,1]
k = [70,165,2]
for i in range(100):
    r.append([random.randint(40,80),random.randint(130,180),1])
    b.append([random.randint(50,100),random.randint(150,200),0])
for i in range(0,100):
    plt.plot(r[i][0],r[i][1],marker='o', linestyle='',color='red')
    plt.plot(b[i][0],b[i][1],marker='o', linestyle='',color='blue')

plt.plot(k[0],k[1],marker='*', linestyle='',color='black')

for i in range (0,100):
    d1.append([distance(new,r[i]),r[i][2]])
    d1.append([distance(new,b[i]),b[i][2]])
    
    
d1 = np.array(d1)
d2 = np.array(d2)
d1.sort()
d2.sort()

z = np.sqrt((new[0] - b[i][0])**2+(new[1] - b[i][1])**2)
for i in range(0,100):
    if (d1[i][0] <= 7):
        if (d1[i][1] == 1):
            man += 1
        elif(d1[i][1] == 0):
            woman += 1

if(woman > man):
    print('여자입니다.')
elif(woman < man):
    print('남자입니다.')
else:
    print('잘못된값입니다.')
def deistance(x,y):
	return int(np.sqrt(pow((x[0]-y[0]),2)+pow((x[1]-y[1]),2)))
# Out:
# 42.5440947723653
# 남자입니다.
